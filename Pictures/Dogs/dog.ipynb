# %%
import pandas as pd
data = pd.read_json("dog.json")
# Print the data 
print(data)
# Out:
#                id          owner      secret  server  farm  \
# 0     51196285470   12608538@N03  1cc4fda304   65535    66
# 1     51195931592  145172533@N07  3159af7482   65535    66
# 2     51196558561   14904436@N00  e7425a099b   65535    66
# 3     51197544145  124304610@N07  a74cddbcfc   65535    66
# 4     51195650487  142433590@N07  c70b820a13   65535    66
# ...           ...            ...         ...     ...   ...
# 5495  49664931493   83090816@N03  b97535ab7b   65535    66
# 5496  49654618916   70142944@N04  4ff4be91ee   65535    66
# 5497  49665687847  185027927@N07  f805593eed   65535    66
# 5498  49617817758  170418689@N03  bc38607559   65535    66
# 5499  49665296896  145106582@N02  84d0cbf224   65535    66
#
#                              title  ispublic  isfriend  isfamily  \
# 0                  PBWA Kensington         1         0         0
# 1                 Huck-bush repose         1         0         0
# ...

# %%
print(data.isnull())
# Out:
#          id  owner  secret  server   farm  title  ispublic  isfriend  \
# 0     False  False   False   False  False  False     False     False
# 1     False  False   False   False  False  False     False     False
# 2     False  False   False   False  False  False     False     False
# 3     False  False   False   False  False  False     False     False
# 4     False  False   False   False  False  False     False     False
# ...     ...    ...     ...     ...    ...    ...       ...       ...
# 5495  False  False   False   False  False  False     False     False
# 5496  False  False   False   False  False  False     False     False
# 5497  False  False   False   False  False  False     False     False
# 5498  False  False   False   False  False  False     False     False
# 5499  False  False   False   False  False  False     False     False
#
#       isfamily  ownername  ...  geo_is_contact  geo_is_friend  geo_is_family  \
# ...

# %%
print(data[data.isnull()])
# Out:
#       id owner secret  server  farm title  ispublic  isfriend  isfamily  \
# 0    NaN   NaN    NaN     NaN   NaN   NaN       NaN       NaN       NaN
# 1    NaN   NaN    NaN     NaN   NaN   NaN       NaN       NaN       NaN
# 2    NaN   NaN    NaN     NaN   NaN   NaN       NaN       NaN       NaN
# 3    NaN   NaN    NaN     NaN   NaN   NaN       NaN       NaN       NaN
# 4    NaN   NaN    NaN     NaN   NaN   NaN       NaN       NaN       NaN
# ...   ..   ...    ...     ...   ...   ...       ...       ...       ...
# 5495 NaN   NaN    NaN     NaN   NaN   NaN       NaN       NaN       NaN
# 5496 NaN   NaN    NaN     NaN   NaN   NaN       NaN       NaN       NaN
# 5497 NaN   NaN    NaN     NaN   NaN   NaN       NaN       NaN       NaN
# 5498 NaN   NaN    NaN     NaN   NaN   NaN       NaN       NaN       NaN
# 5499 NaN   NaN    NaN     NaN   NaN   NaN       NaN       NaN       NaN
#
#      ownername  ...  geo_is_contact geo_is_friend  geo_is_family  media  \
# ...

# %%
data.isna()
# Out:
#          id  owner  secret  server   farm  title  ispublic  isfriend  \
# 0     False  False   False   False  False  False     False     False
# 1     False  False   False   False  False  False     False     False
# 2     False  False   False   False  False  False     False     False
# 3     False  False   False   False  False  False     False     False
# 4     False  False   False   False  False  False     False     False
# ...     ...    ...     ...     ...    ...    ...       ...       ...
# 5495  False  False   False   False  False  False     False     False
# 5496  False  False   False   False  False  False     False     False
# 5497  False  False   False   False  False  False     False     False
# 5498  False  False   False   False  False  False     False     False
# 5499  False  False   False   False  False  False     False     False
#
#       isfamily  ownername  ...  geo_is_contact  geo_is_friend  geo_is_family  \
# ...

# %%
print(data.drop_duplicates())
# Out:
#                id          owner      secret  server  farm  \
# 0     51196285470   12608538@N03  1cc4fda304   65535    66
# 1     51195931592  145172533@N07  3159af7482   65535    66
# 2     51196558561   14904436@N00  e7425a099b   65535    66
# 3     51197544145  124304610@N07  a74cddbcfc   65535    66
# 4     51195650487  142433590@N07  c70b820a13   65535    66
# ...           ...            ...         ...     ...   ...
# 5495  49664931493   83090816@N03  b97535ab7b   65535    66
# 5496  49654618916   70142944@N04  4ff4be91ee   65535    66
# 5497  49665687847  185027927@N07  f805593eed   65535    66
# 5498  49617817758  170418689@N03  bc38607559   65535    66
# 5499  49665296896  145106582@N02  84d0cbf224   65535    66
#
#                              title  ispublic  isfriend  isfamily  \
# 0                  PBWA Kensington         1         0         0
# 1                 Huck-bush repose         1         0         0
# ...
