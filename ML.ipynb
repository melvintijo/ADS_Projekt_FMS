# %% [markdown]
# <a href="https://colab.research.google.com/github/melvintijo/ADS_Projekt_FMS/blob/master/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
DATADIR = "C:/Users/thekkenin/OneDrive - ZHAW\Master/Semester 2/Applied Data Science/Projekt/Pictures"
CATEGORIES = ["Cats","Dogs"]

for category in CATEGORIES:
  path = os.path.join(DATADIR, category)
  for img in os.listdir(path):
    img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
    plt.imshow(img_array, cmp='gray')
    plt.show()
    break
  break
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-e06442a55680> in <module>()
#       4 for category in CATEGORIES:
#       5   path = os.path.join(DATADIR, category)
# ----> 6   for img in os.listdir(path):
#       7     img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
#       8     plt.imshow(img_array, cmp='gray')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/thekkenin/OneDrive - ZHAW\\Master/Semester 2/Applied Data Science/Projekt/Pictures/Cats'
